# %% [markdown]
# # Moral Foundations AI - Colab

# %%
# !pip install torch

# %%
# Upload the zip and unzip
import zipfile
zipfile.ZipFile('moral-foundations-ai.zip').extractall()

# %%
# %cd moral-foundations-ai
# !python train.py

# %%
# !python inference.py
